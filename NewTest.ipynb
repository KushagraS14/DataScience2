# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data2=pd.read_csv('/content/OnlineRetail (2).csv',encoding='unicode_escape')

# %%
data2[data2['Quantity']==data2['Quantity'].max()]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom

# %%
data2[data2['Quantity']==1]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 113       536381     71270                  PHOTO CLIP LINE         1
# 114       536381     22262            FELT EGG COSY CHICKEN         1
# 115       536381     22637            PIGGY BANK RETROSPOT          1
# 118       536381     21166       COOK WITH WINE METAL SIGN          1
# 120       536381    37444A  YELLOW BREAKFAST CUP AND SAUCER         1
# ...          ...       ...                              ...       ...
# 541851    581580     22721    SET OF 3 CAKE TINS SKETCHBOOK         1
# 541855    581580     21351         CINAMMON & ORANGE WREATH         1
# 541856    581580     22698   PINK REGENCY TEACUP AND SAUCER         1
# 541857    581580     22567          20 DOLLY PEGS RETROSPOT         1
# 541859    581580     37500      TEA TIME TEAPOT IN GIFT BOX         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 113      12/1/2010 9:41       1.25     15311.0  United Kingdom
# ...

# %%
data2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
(data2['Quantity']*data2['UnitPrice']).mean()
# Out:
# 17.98779487699964

# %%
data2['Description'].value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
#                                        ...
# Missing                                   1
# historic computer difference?....se       1
# DUSTY PINK CHRISTMAS TREE 30CM            1
# WRAP BLUE RUSSIAN FOLKART                 1
# PINK BERTIE MOBILE PHONE CHARM            1
# Name: count, Length: 4223, dtype: int64

# %% [markdown]
# Create a DataFrame with unique description of item ,count of the item ,total amount paid for the item. Then get the least purchased item.
# *
# 1 point
# A.FILIGREE DIAMANTE CHAIN
# B.GLASS BELL JAR SMALL
# C.GLASS BELL JAR LARGE
# D.All the above

# %%
fk=data2[data2['Quantity']>0]

# %%
gk=fk[fk['Quantity']==fk['Quantity'].min()]

# %%
gk[gk['Description']=='GLASS BELL JAR LARGE']
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
data2['new']=data2['Quantity']*data2['UnitPrice']

# %%
data2[data2['new']==data2['new'].max()]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country       new
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6

# %%
data2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    new
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
data2[data2['UnitPrice']==data2['UnitPrice'].max()]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 222681   C556445         M      Manual        -1  6/10/2011 15:31    38970.0
#
#         CustomerID         Country      new
# 222681     15098.0  United Kingdom -38970.0

# %%
len(data2['InvoiceNo'].unique())
# Out:
# 25900

# %%
gkk=data2.groupby(['InvoiceNo'])

# %%
gkk.nunique()
# Out:
#            StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# InvoiceNo
# 536365             7            7         3            1          5
# 536366             2            2         1            1          1
# 536367            12           12         6            1          9
# 536368             4            4         2            1          2
# 536369             1            1         1            1          1
# ...              ...          ...       ...          ...        ...
# C581484            1            1         1            1          1
# C581490            2            2         2            1          2
# C581499            1            1         1            1          1
# C581568            1            1         1            1          1
# C581569            2            2         2            1          1
#
#            CustomerID  Country  new
# InvoiceNo
# 536365              1        1    5
# 536366              1        1    1
# ...

# %%
col=list(data2.columns)

# %%
data2.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# new                 0
# dtype: int64

# %%
len(data2['InvoiceNo'].unique())
# Out:
# 25900

# %%
data2[['InvoiceNo']].value_counts()
# Out:
# InvoiceNo
# 573585       1114
# 581219        749
# 581492        731
# 580729        721
# 558475        705
#              ...
# 557509          1
# 540264          1
# 540272          1
# 557501          1
# 569420          1
# Name: count, Length: 25900, dtype: int64

# %%
data2.shape
# Out:
# (541909, 9)

# %%
data2.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# new             6204
# dtype: int64

# %%
g=set(data2['InvoiceNo'])

# %%
len(g)
# Out:
# 25900

# %%
data2[data2['Description']=='PARTY BUNTING']
# Out:
#        InvoiceNo StockCode    Description  Quantity      InvoiceDate  \
# 5535      536864     47566  PARTY BUNTING         1  12/3/2010 11:27
# 5656      536865     47566  PARTY BUNTING         3  12/3/2010 11:28
# 6022      536876     47566  PARTY BUNTING         2  12/3/2010 11:36
# 6572      536956     47566  PARTY BUNTING         5  12/3/2010 12:43
# 7904      537065     47566  PARTY BUNTING         5  12/5/2010 11:57
# ...          ...       ...            ...       ...              ...
# 537784    581345     47566  PARTY BUNTING         5  12/8/2011 12:15
# 538825    581417     47566  PARTY BUNTING         8  12/8/2011 15:01
# 539027    581426     47566  PARTY BUNTING         1  12/8/2011 15:31
# 540534    581492     47566  PARTY BUNTING         2  12/9/2011 10:03
# 541318    581497     47566  PARTY BUNTING         5  12/9/2011 10:23
#
#         UnitPrice  CustomerID         Country    new
# 5535         9.32         NaN  United Kingdom   9.32
# ...

# %%
#How many people bought “WHITE HANGING HEART T-LIGHT HOLDER”.
#*

# %%
l=data2[data2['Description']=='WHITE HANGING HEART T-LIGHT HOLDER']

# %%
l
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 0         536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 49        536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66        536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 220       536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 262       536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# ...          ...       ...                                 ...       ...
# 537291    581246    85123A  WHITE HANGING HEART T-LIGHT HOLDER         1
# 537326    581253    85123A  WHITE HANGING HEART T-LIGHT HOLDER         2
# 537852    581356    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 539979    581452    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# 540217    581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#             InvoiceDate  UnitPrice  CustomerID         Country     new
# ...

# %%
l['Quantity'].sum()
# Out:
# 35317

# %%
data2['Description'].value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
#                                        ...
# Missing                                   1
# historic computer difference?....se       1
# DUSTY PINK CHRISTMAS TREE 30CM            1
# WRAP BLUE RUSSIAN FOLKART                 1
# PINK BERTIE MOBILE PHONE CHARM            1
# Name: count, Length: 4223, dtype: int64

# %%
(data2['UnitPrice']* data2['Quantity']).mean()
# Out:
# 17.98779487699964

# %%
y=data2[data2['Country']=='United Kingdom']

# %%
y
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country     new
# ...

# %%
data2[data2['UnitPrice']==data2['UnitPrice'].max()]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 222681   C556445         M      Manual        -1  6/10/2011 15:31    38970.0
#
#         CustomerID         Country      new
# 222681     15098.0  United Kingdom -38970.0

# %%
data2.drop_duplicates(inplace=True)

# %%
data2.dropna(inplace=True)

# %%
data2[data2['Country']=='United Kingdom']
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country     new
# ...

# %%
data2[data2['Quantity']==data2['Quantity'].max()]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country       new
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6
