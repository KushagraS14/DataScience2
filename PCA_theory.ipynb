# %% [markdown]
# #Importing the required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('/content/nba_final.csv')

# %%
df.head()
# Out:
#     Rk         Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 0  170     A.J. Hammons  hammoaj01    C  NaN   24  DAL  22   0   7.4  ...
# 1   58     Aaron Brooks  brookaa01   PG  NaN   32  IND  65   0  13.8  ...
# 2  157     Aaron Gordon  gordoaa01   SF  NaN   21  ORL  80  72  28.7  ...
# 3  352    Adreian Payne  paynead01   PF  NaN   25  MIN  18   0   7.5  ...
# 4   10  Al-Farouq Aminu  aminual01   PF  NaN   26  POR  61  25  29.1  ...
#
#    Conference   Role   Fvot  FRank  Pvot  PRank  Mvot  MRank  Score  Play
# 0        West  Front    786    123   NaN    NaN   NaN    NaN   83.5    No
# 1         Est   Back   2474     64   NaN    NaN   NaN    NaN   48.2    No
# 2         Est  Front  22774     29   NaN    NaN   NaN    NaN   40.0    No
# 3        West  Front    861    120   1.0   52.0   NaN    NaN   75.5    No
# 4        West  Front   4971     69   7.0   23.0   NaN    NaN   42.8    No
#
# [5 rows x 45 columns]

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2891)

# %%
df.isnull().sum(axis=0)
# Out:
# Rk               0
# Player.x         0
# Player_ID        0
# Pos1             0
# Pos2          1396
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG.              4
# X3P              0
# X3PA             0
# X3P.            99
# X2P              0
# X2PA             0
# X2P.            15
# eFG.             4
# FT               0
# FTA              0
# FT.             47
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Salary          62
# mean_views     138
# Season           0
# Conference       0
# Role             0
# Fvot             0
# FRank            0
# Pvot           159
# PRank          159
# Mvot           404
# MRank          404
# Score            0
# Play             0
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# Rk               0
# Player.x         0
# Player_ID        0
# Pos1             0
# Pos2          1396
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG.              4
# X3P              0
# X3PA             0
# X3P.            99
# X2P              0
# X2PA             0
# X2P.            15
# eFG.             4
# FT               0
# FTA              0
# FT.             47
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Salary          62
# mean_views     138
# Season           0
# Conference       0
# Role             0
# Fvot             0
# FRank            0
# Pvot           159
# PRank          159
# Mvot           404
# MRank          404
# Score            0
# Play             0
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0       6
# 1       5
# 2       5
# 3       3
# 4       3
#        ..
# 1403    1
# 1404    1
# 1405    4
# 1406    1
# 1407    1
# Length: 1408, dtype: int64

# %%
df.isnull().sum(axis=1)>4
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1403    False
# 1404    False
# 1405    False
# 1406    False
# 1407    False
# Length: 1408, dtype: bool

# %%
gf=df[df.isnull().sum(axis=1)<5]

# %%
df.shape
# Out:
# (1408, 45)

# %%
df.isnull().sum().value_counts()
# Out:
# 0       33
# 4        2
# 159      2
# 404      2
# 1396     1
# 99       1
# 47       1
# 15       1
# 138      1
# 62       1
# Name: count, dtype: int64

# %%
#df=df.drop('Pos1',axis=1)

# %%
df.fillna(0)
# Out:
#        Rk         Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 0     170     A.J. Hammons  hammoaj01    C    0   24  DAL  22   0   7.4  ...
# 1      58     Aaron Brooks  brookaa01   PG    0   32  IND  65   0  13.8  ...
# 2     157     Aaron Gordon  gordoaa01   SF    0   21  ORL  80  72  28.7  ...
# 3     352    Adreian Payne  paynead01   PF    0   25  MIN  18   0   7.5  ...
# 4      10  Al-Farouq Aminu  aminual01   PF    0   26  POR  61  25  29.1  ...
# ...   ...              ...        ...  ...  ...  ...  ...  ..  ..   ...  ...
# 1403  109     Zach Collins  colliza01    C    0   21  POR  77   0  17.6  ...
# 1404  294      Zach LaVine  lavinza01   SG    0   23  CHI  63  62  34.5  ...
# 1405  308      Zach Lofton  loftoza01   SG    0   26  DET   1   0   4.0  ...
# 1406  393    Zaza Pachulia  pachuza01    C    0   34  DET  68   3  12.9  ...
# 1407  457     Zhaire Smith  smithzh01   SG    0   19  PHI   6   2  18.5  ...
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Encode the categorical columns

# %%
df.select_dtypes('int')
# Out:
#        Rk  Age   G  GS    Fvot  FRank
# 0     170   24  22   0     786    123
# 1      58   32  65   0    2474     64
# 2     157   21  80  72   22774     29
# 3     352   25  18   0     861    120
# 4      10   26  61  25    4971     69
# ...   ...  ...  ..  ..     ...    ...
# 1403  109   21  77   0   16287     74
# 1404  294   23  63  62  519746      7
# 1405  308   26   1   0     136    114
# 1406  393   34  68   3   21525     50
# 1407  457   19   6   2    3985     91
#
# [1408 rows x 6 columns]

# %%
obj=df.select_dtypes('object').columns

# %%
obj
# Out:
# Index(['Player.x', 'Player_ID', 'Pos1', 'Pos2', 'Tm', 'Season', 'Conference',
#        'Role', 'Play'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in obj:
  df[col]=le.fit_transform(df[col])

# %%
#check for data imbalance

# %% [markdown]
# # Machine Learning Process

# %%
df.fillna(0,inplace=True)

# %%
X=df.drop(columns='Play')
y=df['Play']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# #mean centering scaling,standardisation

# %%
#always perform this process after splitting the data into training and testing

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
#apply the logistic regression on the data

# %%
log_reg=LogisticRegression()

# %%
X_train
# Out:
#        Rk  Player.x  Player_ID  Pos1  Pos2  Age  Tm   G  GS    MP  ...  \
# 137   442       205        597     2     4   22  27  37   0   7.9  ...
# 628   118       257        146     3     4   27  28  80  47  26.1  ...
# 1350  430       582        523     4     4   27  21  81   0  26.5  ...
# 801   462       483        561     4     4   24   2  41   0  12.8  ...
# 232   132       356        194     2     4   21   5  42   0   9.2  ...
# ...   ...       ...        ...   ...   ...  ...  ..  ..  ..   ...  ...
# 607   145       228        181     1     4   21   8  38   0   8.7  ...
# 574   495       186        603     4     4   36  15  67   3  22.9  ...
# 1291   49       498         59     2     4   30  12  78  49  27.4  ...
# 852   126       546        155     1     4   23  12  73   1  12.1  ...
# 501   131        93        162     1     4   21  18  52   0  11.2  ...
#
#       Season  Conference  Role    Fvot  FRank  Pvot  PRank  Mvot  MRank  Score
# ...

# %%
y_train
# Out:
# 137     0
# 628     0
# 1350    0
# 801     0
# 232     0
#        ..
# 607     0
# 574     0
# 1291    0
# 852     0
# 501     0
# Name: Play, Length: 1126, dtype: int64

# %%
log_reg.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_reg.coef_
# Out:
# array([[-7.25716041e-04, -1.09655211e-02, -9.36436429e-04,
#         -1.57466172e-04, -2.91966223e-04, -1.86543750e-03,
#         -1.04946486e-03, -2.99682377e-03, -1.73062348e-05,
#         -1.01302910e-03, -7.38605498e-05, -1.80941909e-04,
#         -3.21307769e-05, -1.15087399e-05, -5.13080119e-05,
#         -1.85333036e-05, -6.23885849e-05, -1.30518301e-04,
#         -3.52052852e-05, -3.59891060e-05, -5.67814061e-06,
#         -2.49969944e-05, -4.95024978e-05, -5.01548041e-05,
#         -1.25871614e-04, -1.74919860e-04, -7.27389034e-06,
#         -2.31253240e-05, -2.18546832e-05, -3.25113597e-05,
#         -1.15851793e-04, -1.65177184e-04, -1.24253918e-08,
#          3.30079102e-05, -8.87647578e-05, -4.85048928e-05,
#         -4.74222187e-05,  4.35843666e-06, -5.70939726e-03,
#          1.41795279e-03, -3.68351363e-03,  7.53991653e-04,
#         -3.97997505e-04, -7.38654622e-03]])

# %%
y_pred=log_reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,roc_auc_score

# %%
roc_auc_score(y_test,y_pred)
# Out:
# np.float64(0.8277777777777777)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.975177304964539

# %% [markdown]
# Now we will transformed the data using PCA and check the performance of the model using PCA transformed data

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=0.95)
X_train_pca=pca.fit_transform(X_train)
X_test_pca=pca.transform(X_test)

# %% [markdown]
# Apply logistic regression on the pca transformed data

# %%
X_train_pca
# Out:
# array([[-6069948.1432104 ],
#        [  182052.7457307 ],
#        [ 3883614.433151  ],
#        ...,
#        [-1587545.76026009],
#        [-4819118.47648271],
#        [-5301060.91922683]])

# %%
X_test_pca
# Out:
# array([[13480792.43235338],
#        [10381439.61535071],
#        [-6612775.51862499],
#        [-4692507.97079527],
#        [ 1777358.12506213],
#        [-5597843.35649353],
#        [-2741892.83343484],
#        [-6536041.53670597],
#        [ 4234911.23795433],
#        [ 5783065.5352463 ],
#        [-5421303.44422056],
#        [-2614483.52775912],
#        [  784457.38789177],
#        [-3227707.95860412],
#        [ 3883741.30416427],
#        [-5301077.76858845],
#        [ 2877536.83740945],
#        [-4839386.02451412],
#        [-4872273.51732663],
#        [-4991837.92709137],
#        [ 5382857.33144936],
#        [-3035231.27816304],
#        [ 9273981.46196247],
#        [-4285184.4753724 ],
#        [-4245535.15895725],
#        [-2792250.62745348],
#        [-4313521.20967374],
#        [-5300975.18772472],
#        [-5142259.30564812],
#        [-3971065.69939336],
#        [-4172559.57715173],
#        [ -832658.83044652],
#        [25271812.73369374],
# ...

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred2=log_reg.predict(X_test)

# %%
roc_auc_score(y_test,y_pred)
# Out:
# np.float64(0.8277777777777777)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#separation between the data points

# %%
#to solve the problem of inseparable classification we use lda

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#to solve the problem of inseparable classification data we use lda

# %%
#lda will project the data onto a new axis to make the data easily separable and while doing so it will automatically reduce the dimension

# %%
#the new axis the lda will create should follow these two criterias

# %%
#it should maximise the means of two class categories
#minimise the variation within each class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
