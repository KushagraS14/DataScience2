# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('//content//bank-additional-full.csv',sep=";") #otherwise the data is not propertly filtered or read in this particuar scenerioo

# %%
data.head() # now everything has been properly distinguished
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
# ...

# %%
#Maximum value is categorical value

# %%
data.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41195.000000  41196.000000  41196.000000  41196.000000  41196.000000
# mean      40.030319    258.281265      2.567676    962.482547      0.173124
# std       10.431818    259.254211      2.769751    186.893451      0.494987
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41196.000000    41195.000000   41196.000000  41196.000000  41196.000000
# mean       0.081656       93.575867     -40.504600      3.620787   5166.996405
# ...

# %%
data.shape #shape defines the number of rows and columns

#4199 rows
#21 columns
# Out:
# (41199, 21)

# %%
data.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
c= data['marital'].value_counts()

# %%
c
# Out:
# marital
# married     24934
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64

# %%
col=list(data.columns)

# %%
col
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %% [markdown]
# Boxplot

# %% [markdown]
# # Using boxplot visualisation we will be able to detect the outliers from a given dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for col_name in col:
  if(data[col_name].dtypes=='int64' or data[col_name].dtypes=='float64'):
    sns.boxplot(data[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# With reference of the above plot we can say there are columns with outliers
#
# 1.   Age
# 2.   Duration
#
#
# 3. Campaign
# 4. con.conf.idx

# %%
col_name=['age','duration','campaign','cons.conf.idx']

# %%
q1=data['age'].quantile(0.25)
q3=data['age'].quantile(0.75)
iqr=q3-q1
data=data[(data['age']>=q1-1.5*iqr)|(data['age']<=q3+1.5*iqr)]

# %%
q1=data['duration'].quantile(0.25)
q3=data['duration'].quantile(0.75)
iqr=q3-q1
data=data[(data['duration']>=q1-1.5*iqr)|(data['duration']<=q3+1.5*iqr)]

# %%
q1=data['campaign'].quantile(0.25)
q3=data['campaign'].quantile(0.75)
iqr=q3-q1
data=data[(data['campaign']>=q1-1.5*iqr)|(data['campaign']<=q3+1.5*iqr)]

# %%
q1=data['cons.conf.idx'].quantile(0.25)
q3=data['cons.conf.idx'].quantile(0.75)
iqr=q3-q1
data=data[(data['cons.conf.idx']>=q1-1.5*iqr)|(data['cons.conf.idx']<=q3+1.5*iqr)]

# %%
for col_name in col:
  if(data[col_name].dtypes=='int64' or data[col_name].dtypes=='float64'):
    sns.boxplot(data[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()

# %%
data.isnull().sum()
# Out:
# age               0
# job               2
# marital           1
# education         2
# default           1
# housing           0
# loan              1
# contact           1
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          1
# emp.var.rate      0
# cons.price.idx    1
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 10

# %%
#Whenever we are doing model building we can't deal with object data types.because machine can only learn with numbers!!

# %%
data['y']=np.where(data['y']=='yes',1,0)  #it converted into int

# %%
data['y']=data['y'].astype('str')   #because initially it was object datatype so we need to convert it again to string

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41195 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41193 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41193 non-null  object
#  4   default         41194 non-null  object
#  5   housing         41195 non-null  object
#  6   loan            41194 non-null  object
#  7   contact         41194 non-null  object
#  8   month           41195 non-null  object
#  9   day_of_week     41195 non-null  object
#  10  duration        41195 non-null  float64
#  11  campaign        41195 non-null  float64
#  12  pdays           41195 non-null  float64
#  13  previous        41195 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41195 non-null  float64
#  16  cons.price.idx  41194 non-null  float64
# ...

# %%
data
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41193  94.0    retired  married  professional.course       no     yes   no
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
# ...

# %%
#data

# %%
bins=[0,50,100]                              #Duplicate data types  and at the same time theyare not duplicate data
data['age']=pd.cut(data['age'],bins)
data['age']=data.age.astype('str')

# %%
data['age'].value_counts()
# Out:
# age
# (0, 50]      34008
# (50, 100]     7187
# Name: count, dtype: int64

# %%
data
# Out:
#              age        job  marital            education  default housing  \
# 0      (50, 100]  housemaid  married             basic.4y       no      no
# 1      (50, 100]   services  married          high.school  unknown      no
# 2        (0, 50]   services  married          high.school       no     yes
# 3        (0, 50]     admin.  married             basic.6y       no      no
# 4      (50, 100]   services  married          high.school       no      no
# ...          ...        ...      ...                  ...      ...     ...
# 41193  (50, 100]    retired  married  professional.course       no     yes
# 41194  (50, 100]    retired  married  professional.course       no     yes
# 41195  (50, 100]        NaN  married  professional.course       no     yes
# 41196  (50, 100]    retired  married                  NaN       no     yes
# 41198  (50, 100]    retired  married  professional.course       no     yes
#
# ...

# %%
col_list=list(data.columns)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %%
for col in col_list:
  if data[col].dtype=='object':
    data[col]=data[col].fillna(data[col].mode()[0])
  else:
    data[col]=data[col].fillna(data[col].mean())

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data
# Out:
#              age        job  marital            education  default housing  \
# 0      (50, 100]  housemaid  married             basic.4y       no      no
# 1      (50, 100]   services  married          high.school  unknown      no
# 2        (0, 50]   services  married          high.school       no     yes
# 3        (0, 50]     admin.  married             basic.6y       no      no
# 4      (50, 100]   services  married          high.school       no      no
# ...          ...        ...      ...                  ...      ...     ...
# 41193  (50, 100]    retired  married  professional.course       no     yes
# 41194  (50, 100]    retired  married  professional.course       no     yes
# 41195  (50, 100]     admin.  married  professional.course       no     yes
# 41196  (50, 100]    retired  married    university.degree       no     yes
# 41198  (50, 100]    retired  married  professional.course       no     yes
#
# ...

# %%
col_list=list(data.columns)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()

# %%
#doing this individually would be a tedious task

# %%
for i in col_list:
  data[i]=labelencoder.fit_transform(data[i])

# %%
data  #everyvalue is being converted into a numerical value
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        1    3        1          0        0        0     0        1      6
# 1        1    7        1          3        1        0     0        1      6
# 2        0    7        1          3        0        2     0        1      6
# 3        0    0        1          1        0        0     0        1      6
# 4        1    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41193    1    5        1          5        0        2     0        0      7
# 41194    1    5        1          5        0        2     0        0      7
# 41195    1    0        1          5        0        2     0        0      7
# 41196    1    5        1          6        0        2     0        0      7
# 41198    1    5        1          5        0        2     0        0      7
#
# ...

# %% [markdown]
# Chi Square

# %% [markdown]
# *  A feature selection method for classifaction data /problems

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        1    3        1          0        0        0     0        1      6
# 1        1    7        1          3        1        0     0        1      6
# 2        0    7        1          3        0        2     0        1      6
# 3        0    0        1          1        0        0     0        1      6
# 4        1    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41193    1    5        1          5        0        2     0        0      7
# 41194    1    5        1          5        0        2     0        0      7
# 41195    1    0        1          5        0        2     0        0      7
# 41196    1    5        1          6        0        2     0        0      7
# 41198    1    5        1          5        0        2     0        0      7
#
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41193    0
# 41194    0
# 41195    0
# 41196    0
# 41198    0
# Name: y, Length: 41195, dtype: int64

# %%
chi2_feature=SelectKBest(chi2,k=10)  #select k best is a method which is used to select the best columns based on and store the method in a variable.At least we need 3 columns for model building purpose.

# %%
x_best_features=chi2_feature.fit_transform(x,y)

# %%
print("Selected_features_indices:",chi2_feature.get_support(indices=True))
# Out:
# Selected_features_indices: [ 7 10 11 12 13 15 16 17 18 19]

# %%
selected_indices=chi2_feature.get_support(indices=True)

# %%
selected_indices
# Out:
# array([ 7, 10, 11, 12, 13, 15, 16, 17, 18, 19])

# %%
column_names=x.columns

# %%
column_names
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
selected_column_names=[column_names[i] for i in selected_indices] #Any value that is matching with selected indices

# %%
selected_column_names
# Out:
# ['contact',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %% [markdown]
# Variance Inflation Factor-Generally we calculate the correlation all  the columns,dropping the columns having values greater than 6.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in data.columns:
  if ((data[col].dtype !='object' ) & (col!='y')):
    col_list.append(col)

  x=data[col_list]
  Vif_data=pd.DataFrame()
  Vif_data['Features']=x.columns
  Vif_data['VIF']=[variance_inflation_factor(x.values,i)  for i in range(len(x.columns))]
  print(Vif_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-1c1e1e70e10b> in <cell line: 3>()
#       8   Vif_data=pd.DataFrame()
#       9   Vif_data['Features']=x.columns
# ---> 10   Vif_data['VIF']=[variance_inflation_factor(x.values,i)  for i in range(len(x.columns))]
#      11   print(Vif_data)
#
# <ipython-input-62-1c1e1e70e10b> in <listcomp>(.0)
#       8   Vif_data=pd.DataFrame()
#       9   Vif_data['Features']=x.columns
# ---> 10   Vif_data['VIF']=[variance_inflation_factor(x.values,i)  for i in range(len(x.columns))]
#      11   print(Vif_data)
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     194     mask = np.arange(k_vars) != exog_idx
#     195     x_noti = exog[:, mask]
# --> 196     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     197     vif = 1. / (1. - r_squared_i)
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
  if((data[col].dtype != 'object') & (col != 'y')):
    col_list.append(col)

x = data[col_list]
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in data.columns:
  if ((data[col].dtype!='object') & (col !='y')):
      col_list.append(col)

vif=pd.DataFrame()
x=data[col_list]
vif['features']=x.columns
vif['vif']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif)
# Out:
#           features         vif
# 0              age    1.319709
# 1              job    2.120236
# 2          marital    5.030110
# 3        education    4.432132
# 4          default    1.385757
# 5          housing    2.202305
# 6             loan    1.207144
# 7          contact    4.422545
# 8            month    5.401541
# 9      day_of_week    3.076832
# 10        duration    2.167517
# 11        campaign    1.372867
# 12           pdays   67.148507
# 13        previous    2.050677
# 14        poutcome   12.081090
# 15    emp.var.rate  150.941897
# 16  cons.price.idx   66.018827
# 17   cons.conf.idx    9.635081
# 18       euribor3m  137.220075
# 19     nr.employed  134.224091

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in data.columns:
  if ((data[col].dtype !='object' ) & (col!='y')):
    col_list.append(col)

# %%
X=data[col_list]
X.values

# %%
data=data.drop(columns='euribor3m',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
  if((data[col].dtype != 'object') & (col != 'y')):
    col_list.append(col)

x = data[col_list]
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)

# %%
data=data.drop(columns='emp.var.rate',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
  if((data[col].dtype != 'object') & (col != 'y')):
    col_list.append(col)

x = data[col_list]
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)

# %%
data=data.drop(columns='pdays',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
  if((data[col].dtype != 'object') & (col != 'y')):
    col_list.append(col)

x = data[col_list]
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)

# %%
data=data.drop(columns='cons.price.idx',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
  if((data[col].dtype != 'object') & (col != 'y')):
    col_list.append(col)

x = data[col_list]
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)

# %%
data=data.drop(columns='nr.employed',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
  if((data[col].dtype != 'object') & (col != 'y')):
    col_list.append(col)

x = data[col_list]
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)

# %%
data=data.drop(columns='poutcome',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
  if((data[col].dtype != 'object') & (col != 'y')):
    col_list.append(col)

x = data[col_list]
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)

# %%
data

# %% [markdown]
# RFE

# %% [markdown]
# RECURSIVE FEATURE ELIMINATION

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x

# %%
y

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
rfe=RFE(model)

# %%
rfe.fit(x,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
rfe.support_

# %%
selected_indices=[i for i,data in enumerate(rfe.support_)if data==True]
selected_indices

# %%
column_names=x.columns

# %%
selected_columns=[column_names[i] for i in selected_indices]

# %%
selected_columns

# %% [markdown]
# RECURSIVE FEATURE ELIMINATION IS A METHOD WHICH RECURSIVELY CHOOSE EACH AND EVERY COLUMN.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# x->FEATURES
# Y->TARGET COLUMN
# IT CHOOSE THE NUMBER OF FEATURES BASED ON THE TARGET VARIABLE AND THE MODEL

# %% [markdown]
# AFTER CHOOSING THE MODEL WE SELECT TH COLUMNS IN BINARY FORMAT TRUE FOR THE COLUMN WE NEED TO SELECT AND FALSE FOR THECOLUMNS WE WON'T BES SELECTING

# %%
a=[1,2,3,4]
for i, j in enumerate(a):
  print(i ,j)

# %%
print(enumerate(a))

# %%
x=x.loc[:,['age', 'marital', 'default', 'housing', 'contact', 'month', 'cons.conf.idx']]

# %%
y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=199)

# %%
x_train

# %%
x_test

# %%
y_train

# %%
y_test

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print("Accuracy score of the model is ",accuracy_score(y_test,y_pred))

# %%
confusion_matrix(y_test,y_pred)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
